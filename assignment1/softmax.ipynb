# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
# 'cs231n' folder containing the '.py', 'classifiers' and 'datasets'
# folders.
# e.g. 'cs231n/assignments/assignment1/cs231n/'
FOLDERNAME = 'cs231n/assignments/assignment1/cs231n/'

assert FOLDERNAME is not None, "[!] Enter the foldername."

# %cd drive/My\ Drive
# %cp -r $FOLDERNAME ../../
# %cd ../../
# %cd cs231n/datasets/
# !bash get_datasets.sh
# %cd ../../
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# /content
# /content/cs231n/datasets
# --2020-06-02 10:36:14--  http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz’
#
# cifar-10-python.tar 100%[===================>] 162.60M  15.9MB/s    in 12s
#
# 2020-06-02 10:36:27 (14.0 MB/s) - ‘cifar-10-python.tar.gz’ saved [170498071/170498071]
#
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1
# /content

# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.333011
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.
#
# $\color{blue}{\textit Your Answer:}$ As we are not performing a learning process and just calculating the softmax based on some initial random weights, we expect that the initial loss has to be close to -log(0.1) because initially all the classes are equally likely to be chosen. In CIFAR-10 we have 10 classes, thus probability of the correct class will be 0.1 and the softmax loss is the negative log probability of the correct class, therefore it is -log(0.1).

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.424569 analytic: -0.424569, relative error: 5.766313e-08
# numerical: -0.935438 analytic: -0.935438, relative error: 4.926673e-08
# numerical: 1.243773 analytic: 1.243773, relative error: 9.487704e-08
# numerical: -1.846613 analytic: -1.846613, relative error: 1.075950e-08
# numerical: 0.790308 analytic: 0.790308, relative error: 5.493862e-09
# numerical: -1.601841 analytic: -1.601841, relative error: 2.741370e-08
# numerical: 0.691632 analytic: 0.691632, relative error: 5.380131e-08
# numerical: 1.603010 analytic: 1.603009, relative error: 3.867926e-08
# numerical: 1.207457 analytic: 1.207457, relative error: 3.307249e-08
# numerical: 3.556984 analytic: 3.556984, relative error: 1.774086e-08
# numerical: 0.481811 analytic: 0.481810, relative error: 6.473186e-08
# numerical: -1.194784 analytic: -1.194784, relative error: 7.013992e-08
# numerical: -0.723299 analytic: -0.723299, relative error: 9.128537e-08
# numerical: -2.650049 analytic: -2.650050, relative error: 4.239313e-08
# numerical: -1.631502 analytic: -1.631502, relative error: 7.820187e-09
# numerical: 0.108906 analytic: 0.108906, relative error: 2.108477e-07
# numerical: -0.081704 analytic: -0.081704, relative error: 3.090490e-07
# numerical: -0.923698 analytic: -0.923698, relative error: 2.501818e-08
# numerical: 1.665111 analytic: 1.665111, relative error: 8.490726e-09
# numerical: 0.000583 analytic: 0.000583, relative error: 3.859714e-05

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.333011e+00 computed in 0.213217s
# vectorized loss: 2.333011e+00 computed in 0.011016s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.

from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

# Provided as a reference. You may or may not want to change these hyperparameters
learning_rates = [1e-6, 2e-6, 5e-6, 1e-7, 2e-7, 5e-7, 1e-8, 2e-8, 5e-8]
regularization_strengths = [2.5e4, 3e4, 3.5e4, 4e4, 4.5e4, 5e4, 5.5e4, 6e4]

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

hyperparameters = [(lr, rg) for lr in learning_rates for rg in regularization_strengths]

for lr, rg in hyperparameters:
    softmax = Softmax()
    tr_loss = softmax.train(X_train, y_train, learning_rate = lr, reg = rg, num_iters = 1500, verbose = True)
    y_train_pred = softmax.predict(X_train)
    tr_acc = np.mean(y_train_pred == y_train)
    y_val_pred = softmax.predict(X_val)
    val_acc = np.mean(y_val_pred == y_val)
    results[(lr, rg)] = (tr_acc, val_acc)
    if(best_val < val_acc):
        best_val = val_acc
        best_softmax = softmax
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 777.510524
# iteration 100 / 1500: loss 2.128400
# iteration 200 / 1500: loss 2.115234
# iteration 300 / 1500: loss 2.077695
# iteration 400 / 1500: loss 2.087885
# iteration 500 / 1500: loss 2.136746
# iteration 600 / 1500: loss 2.124016
# iteration 700 / 1500: loss 2.063590
# iteration 800 / 1500: loss 2.103407
# iteration 900 / 1500: loss 2.109839
# iteration 1000 / 1500: loss 2.084939
# iteration 1100 / 1500: loss 2.092996
# iteration 1200 / 1500: loss 2.109319
# iteration 1300 / 1500: loss 2.177011
# iteration 1400 / 1500: loss 2.019214
# iteration 0 / 1500: loss 924.168665
# iteration 100 / 1500: loss 2.151731
# iteration 200 / 1500: loss 2.145335
# iteration 300 / 1500: loss 2.134839
# iteration 400 / 1500: loss 2.090699
# iteration 500 / 1500: loss 2.134131
# iteration 600 / 1500: loss 2.130589
# iteration 700 / 1500: loss 2.119151
# iteration 800 / 1500: loss 2.080279
# iteration 900 / 1500: loss 2.066706
# iteration 1000 / 1500: loss 2.040600
# iteration 1100 / 1500: loss 2.162238
# iteration 1200 / 1500: loss 2.084054
# iteration 1300 / 1500: loss 2.148453
# iteration 1400 / 1500: loss 2.129366
# iteration 0 / 1500: loss 1083.833013
# iteration 100 / 1500: loss 2.126849
# iteration 200 / 1500: loss 2.103054
# iteration 300 / 1500: loss 2.065264
# iteration 400 / 1500: loss 2.164038
# iteration 500 / 1500: loss 2.191080
# iteration 600 / 1500: loss 2.143157
# iteration 700 / 1500: loss 2.132706
# iteration 800 / 1500: loss 2.096399
# iteration 900 / 1500: loss 2.102540
# iteration 1000 / 1500: loss 2.091215
# iteration 1100 / 1500: loss 2.190549
# iteration 1200 / 1500: loss 2.156347
# iteration 1300 / 1500: loss 2.125873
# iteration 1400 / 1500: loss 2.115841
# iteration 0 / 1500: loss 1226.150012
# iteration 100 / 1500: loss 2.164730
# iteration 200 / 1500: loss 2.175570
# iteration 300 / 1500: loss 2.113479
# iteration 400 / 1500: loss 2.139170
# iteration 500 / 1500: loss 2.148837
# iteration 600 / 1500: loss 2.155629
# iteration 700 / 1500: loss 2.145923
# iteration 800 / 1500: loss 2.129330
# iteration 900 / 1500: loss 2.131841
# iteration 1000 / 1500: loss 2.074025
# iteration 1100 / 1500: loss 2.152506
# iteration 1200 / 1500: loss 2.172492
# iteration 1300 / 1500: loss 2.147972
# iteration 1400 / 1500: loss 2.109768
# iteration 0 / 1500: loss 1396.175923
# iteration 100 / 1500: loss 2.142829
# iteration 200 / 1500: loss 2.172473
# iteration 300 / 1500: loss 2.144861
# iteration 400 / 1500: loss 2.152030
# iteration 500 / 1500: loss 2.176303
# iteration 600 / 1500: loss 2.168022
# iteration 700 / 1500: loss 2.132937
# iteration 800 / 1500: loss 2.201994
# iteration 900 / 1500: loss 2.175987
# iteration 1000 / 1500: loss 2.135923
# iteration 1100 / 1500: loss 2.135614
# iteration 1200 / 1500: loss 2.177923
# iteration 1300 / 1500: loss 2.143145
# iteration 1400 / 1500: loss 2.175925
# iteration 0 / 1500: loss 1542.908361
# iteration 100 / 1500: loss 2.144468
# iteration 200 / 1500: loss 2.161534
# iteration 300 / 1500: loss 2.142480
# iteration 400 / 1500: loss 2.154568
# iteration 500 / 1500: loss 2.188919
# iteration 600 / 1500: loss 2.147840
# iteration 700 / 1500: loss 2.142245
# iteration 800 / 1500: loss 2.187008
# iteration 900 / 1500: loss 2.175233
# iteration 1000 / 1500: loss 2.162827
# iteration 1100 / 1500: loss 2.222457
# iteration 1200 / 1500: loss 2.122111
# iteration 1300 / 1500: loss 2.185279
# iteration 1400 / 1500: loss 2.164411
# iteration 0 / 1500: loss 1690.494585
# iteration 100 / 1500: loss 2.220228
# iteration 200 / 1500: loss 2.142127
# iteration 300 / 1500: loss 2.178743
# iteration 400 / 1500: loss 2.160470
# iteration 500 / 1500: loss 2.130189
# iteration 600 / 1500: loss 2.164372
# iteration 700 / 1500: loss 2.168347
# iteration 800 / 1500: loss 2.137430
# iteration 900 / 1500: loss 2.159027
# iteration 1000 / 1500: loss 2.099309
# iteration 1100 / 1500: loss 2.182437
# iteration 1200 / 1500: loss 2.137552
# iteration 1300 / 1500: loss 2.151899
# iteration 1400 / 1500: loss 2.130282
# iteration 0 / 1500: loss 1848.571457
# iteration 100 / 1500: loss 2.135759
# iteration 200 / 1500: loss 2.181494
# iteration 300 / 1500: loss 2.171200
# iteration 400 / 1500: loss 2.254216
# iteration 500 / 1500: loss 2.128474
# iteration 600 / 1500: loss 2.153326
# iteration 700 / 1500: loss 2.189482
# iteration 800 / 1500: loss 2.181351
# iteration 900 / 1500: loss 2.121736
# iteration 1000 / 1500: loss 2.130792
# iteration 1100 / 1500: loss 2.130240
# iteration 1200 / 1500: loss 2.165967
# iteration 1300 / 1500: loss 2.122285
# iteration 1400 / 1500: loss 2.127368
# iteration 0 / 1500: loss 775.117298
# iteration 100 / 1500: loss 2.114840
# iteration 200 / 1500: loss 2.106548
# iteration 300 / 1500: loss 2.186245
# iteration 400 / 1500: loss 2.089228
# iteration 500 / 1500: loss 2.150707
# iteration 600 / 1500: loss 2.068770
# iteration 700 / 1500: loss 2.141694
# iteration 800 / 1500: loss 2.134970
# iteration 900 / 1500: loss 2.095031
# iteration 1000 / 1500: loss 2.122368
# iteration 1100 / 1500: loss 2.095842
# iteration 1200 / 1500: loss 2.110984
# iteration 1300 / 1500: loss 2.096983
# iteration 1400 / 1500: loss 2.121407
# iteration 0 / 1500: loss 922.829084
# iteration 100 / 1500: loss 2.151447
# iteration 200 / 1500: loss 2.119689
# iteration 300 / 1500: loss 2.185886
# iteration 400 / 1500: loss 2.158435
# iteration 500 / 1500: loss 2.152437
# iteration 600 / 1500: loss 2.164317
# iteration 700 / 1500: loss 2.157338
# iteration 800 / 1500: loss 2.134147
# iteration 900 / 1500: loss 2.100091
# iteration 1000 / 1500: loss 2.140572
# iteration 1100 / 1500: loss 2.135645
# iteration 1200 / 1500: loss 2.120985
# iteration 1300 / 1500: loss 2.167056
# iteration 1400 / 1500: loss 2.164422
# iteration 0 / 1500: loss 1073.835616
# iteration 100 / 1500: loss 2.102467
# iteration 200 / 1500: loss 2.125883
# iteration 300 / 1500: loss 2.133650
# iteration 400 / 1500: loss 2.096234
# iteration 500 / 1500: loss 2.164867
# iteration 600 / 1500: loss 2.135839
# iteration 700 / 1500: loss 2.142634
# iteration 800 / 1500: loss 2.106808
# iteration 900 / 1500: loss 2.156094
# iteration 1000 / 1500: loss 2.142059
# iteration 1100 / 1500: loss 2.140549
# iteration 1200 / 1500: loss 2.073401
# iteration 1300 / 1500: loss 2.171812
# iteration 1400 / 1500: loss 2.219559
# iteration 0 / 1500: loss 1236.352572
# iteration 100 / 1500: loss 2.149453
# iteration 200 / 1500: loss 2.142925
# iteration 300 / 1500: loss 2.181227
# iteration 400 / 1500: loss 2.185352
# iteration 500 / 1500: loss 2.170663
# iteration 600 / 1500: loss 2.137305
# iteration 700 / 1500: loss 2.187551
# iteration 800 / 1500: loss 2.164448
# iteration 900 / 1500: loss 2.218060
# iteration 1000 / 1500: loss 2.170924
# iteration 1100 / 1500: loss 2.210520
# iteration 1200 / 1500: loss 2.156420
# iteration 1300 / 1500: loss 2.119408
# iteration 1400 / 1500: loss 2.213857
# iteration 0 / 1500: loss 1387.314403
# iteration 100 / 1500: loss 2.136636
# iteration 200 / 1500: loss 2.181616
# iteration 300 / 1500: loss 2.141900
# iteration 400 / 1500: loss 2.166443
# iteration 500 / 1500: loss 2.188962
# iteration 600 / 1500: loss 2.109797
# iteration 700 / 1500: loss 2.141302
# iteration 800 / 1500: loss 2.177686
# iteration 900 / 1500: loss 2.198003
# iteration 1000 / 1500: loss 2.118461
# iteration 1100 / 1500: loss 2.193187
# iteration 1200 / 1500: loss 2.163260
# iteration 1300 / 1500: loss 2.158563
# iteration 1400 / 1500: loss 2.167597
# iteration 0 / 1500: loss 1534.460498
# iteration 100 / 1500: loss 2.207982
# iteration 200 / 1500: loss 2.146072
# iteration 300 / 1500: loss 2.193739
# iteration 400 / 1500: loss 2.180925
# iteration 500 / 1500: loss 2.236376
# iteration 600 / 1500: loss 2.155395
# iteration 700 / 1500: loss 2.157864
# iteration 800 / 1500: loss 2.177513
# iteration 900 / 1500: loss 2.171435
# iteration 1000 / 1500: loss 2.153650
# iteration 1100 / 1500: loss 2.241671
# iteration 1200 / 1500: loss 2.144993
# iteration 1300 / 1500: loss 2.159419
# iteration 1400 / 1500: loss 2.164064
# iteration 0 / 1500: loss 1683.422674
# iteration 100 / 1500: loss 2.134806
# iteration 200 / 1500: loss 2.198405
# iteration 300 / 1500: loss 2.123807
# iteration 400 / 1500: loss 2.209096
# iteration 500 / 1500: loss 2.175345
# iteration 600 / 1500: loss 2.168486
# iteration 700 / 1500: loss 2.122816
# iteration 800 / 1500: loss 2.152588
# iteration 900 / 1500: loss 2.184685
# iteration 1000 / 1500: loss 2.170269
# iteration 1100 / 1500: loss 2.202332
# iteration 1200 / 1500: loss 2.176479
# iteration 1300 / 1500: loss 2.229578
# iteration 1400 / 1500: loss 2.213051
# iteration 0 / 1500: loss 1843.571086
# iteration 100 / 1500: loss 2.217762
# iteration 200 / 1500: loss 2.192559
# iteration 300 / 1500: loss 2.227312
# iteration 400 / 1500: loss 2.196580
# iteration 500 / 1500: loss 2.225643
# iteration 600 / 1500: loss 2.179923
# iteration 700 / 1500: loss 2.180999
# iteration 800 / 1500: loss 2.176830
# iteration 900 / 1500: loss 2.209176
# iteration 1000 / 1500: loss 2.176901
# iteration 1100 / 1500: loss 2.191340
# iteration 1200 / 1500: loss 2.192457
# iteration 1300 / 1500: loss 2.172737
# iteration 1400 / 1500: loss 2.237075
# iteration 0 / 1500: loss 777.065211
# iteration 100 / 1500: loss 2.423843
# iteration 200 / 1500: loss 2.964107
# iteration 300 / 1500: loss 2.352781
# iteration 400 / 1500: loss 2.402486
# iteration 500 / 1500: loss 2.651999
# iteration 600 / 1500: loss 2.609599
# iteration 700 / 1500: loss 2.365093
# iteration 800 / 1500: loss 2.728105
# iteration 900 / 1500: loss 2.367581
# iteration 1000 / 1500: loss 2.402778
# iteration 1100 / 1500: loss 2.805678
# iteration 1200 / 1500: loss 2.371842
# iteration 1300 / 1500: loss 2.475805
# iteration 1400 / 1500: loss 2.581984
# iteration 0 / 1500: loss 931.176969
# iteration 100 / 1500: loss 2.676662
# iteration 200 / 1500: loss 2.508490
# iteration 300 / 1500: loss 2.619992
# iteration 400 / 1500: loss 2.566165
# iteration 500 / 1500: loss 2.953075
# iteration 600 / 1500: loss 2.899050
# iteration 700 / 1500: loss 2.819351
# iteration 800 / 1500: loss 2.420456
# iteration 900 / 1500: loss 2.396158
# iteration 1000 / 1500: loss 2.400710
# iteration 1100 / 1500: loss 2.519523
# iteration 1200 / 1500: loss 2.706410
# iteration 1300 / 1500: loss 3.054592
# iteration 1400 / 1500: loss 2.477605
# iteration 0 / 1500: loss 1081.981494
# iteration 100 / 1500: loss 2.407148
# iteration 200 / 1500: loss 2.465213
# iteration 300 / 1500: loss 2.456288
# iteration 400 / 1500: loss 3.050267
# iteration 500 / 1500: loss 3.181154
# iteration 600 / 1500: loss 3.151846
# iteration 700 / 1500: loss 2.534805
# iteration 800 / 1500: loss 2.831253
# iteration 900 / 1500: loss 3.114416
# iteration 1000 / 1500: loss 2.628492
# iteration 1100 / 1500: loss 2.580625
# iteration 1200 / 1500: loss 3.449881
# iteration 1300 / 1500: loss 2.897152
# iteration 1400 / 1500: loss 2.411994
# iteration 0 / 1500: loss 1244.844269
# iteration 100 / 1500: loss 2.906417
# iteration 200 / 1500: loss 3.297468
# iteration 300 / 1500: loss 2.566629
# iteration 400 / 1500: loss 3.140080
# iteration 500 / 1500: loss 2.990747
# iteration 600 / 1500: loss 3.032794
# iteration 700 / 1500: loss 2.787083
# iteration 800 / 1500: loss 2.816630
# iteration 900 / 1500: loss 3.624359
# iteration 1000 / 1500: loss 2.614649
# iteration 1100 / 1500: loss 3.067331
# iteration 1200 / 1500: loss 3.346968
# iteration 1300 / 1500: loss 3.495906
# iteration 1400 / 1500: loss 3.378117
# iteration 0 / 1500: loss 1405.185491
# iteration 100 / 1500: loss 3.029550
# iteration 200 / 1500: loss 3.160675
# iteration 300 / 1500: loss 3.203277
# iteration 400 / 1500: loss 3.286870
# iteration 500 / 1500: loss 2.981549
# iteration 600 / 1500: loss 3.277719
# iteration 700 / 1500: loss 2.982867
# iteration 800 / 1500: loss 3.788394
# iteration 900 / 1500: loss 3.384797
# iteration 1000 / 1500: loss 2.974985
# iteration 1100 / 1500: loss 4.398698
# iteration 1200 / 1500: loss 3.575065
# iteration 1300 / 1500: loss 3.220846
# iteration 1400 / 1500: loss 3.047155
# iteration 0 / 1500: loss 1541.142081
# iteration 100 / 1500: loss 4.291169
# iteration 200 / 1500: loss 3.086112
# iteration 300 / 1500: loss 3.409112
# iteration 400 / 1500: loss 3.576297
# iteration 500 / 1500: loss 3.660278
# iteration 600 / 1500: loss 3.167670
# iteration 700 / 1500: loss 3.177505
# iteration 800 / 1500: loss 2.674569
# iteration 900 / 1500: loss 2.922667
# iteration 1000 / 1500: loss 3.005083
# iteration 1100 / 1500: loss 4.193276
# iteration 1200 / 1500: loss 2.832689
# iteration 1300 / 1500: loss 2.494311
# iteration 1400 / 1500: loss 4.791431
# iteration 0 / 1500: loss 1701.154224
# iteration 100 / 1500: loss 3.155019
# iteration 200 / 1500: loss 3.313001
# iteration 300 / 1500: loss 4.937132
# iteration 400 / 1500: loss 3.712974
# iteration 500 / 1500: loss 3.808055
# iteration 600 / 1500: loss 3.923699
# iteration 700 / 1500: loss 3.900796
# iteration 800 / 1500: loss 3.767335
# iteration 900 / 1500: loss 2.824265
# iteration 1000 / 1500: loss 4.985751
# iteration 1100 / 1500: loss 4.387245
# iteration 1200 / 1500: loss 4.595210
# iteration 1300 / 1500: loss 4.580844
# iteration 1400 / 1500: loss 2.876453
# iteration 0 / 1500: loss 1834.816587
# iteration 100 / 1500: loss 3.950115
# iteration 200 / 1500: loss 3.222444
# iteration 300 / 1500: loss 4.318226
# iteration 400 / 1500: loss 4.063783
# iteration 500 / 1500: loss 5.506877
# iteration 600 / 1500: loss 4.395907
# iteration 700 / 1500: loss 4.050026
# iteration 800 / 1500: loss 3.290043
# iteration 900 / 1500: loss 4.177028
# iteration 1000 / 1500: loss 5.374313
# iteration 1100 / 1500: loss 3.581130
# iteration 1200 / 1500: loss 3.684046
# iteration 1300 / 1500: loss 4.024848
# iteration 1400 / 1500: loss 4.672358
# iteration 0 / 1500: loss 770.079284
# iteration 100 / 1500: loss 283.181660
# iteration 200 / 1500: loss 104.960798
# iteration 300 / 1500: loss 39.724141
# iteration 400 / 1500: loss 15.882055
# iteration 500 / 1500: loss 7.133370
# iteration 600 / 1500: loss 3.941866
# iteration 700 / 1500: loss 2.801806
# iteration 800 / 1500: loss 2.355792
# iteration 900 / 1500: loss 2.219583
# iteration 1000 / 1500: loss 2.101442
# iteration 1100 / 1500: loss 2.053645
# iteration 1200 / 1500: loss 2.121825
# iteration 1300 / 1500: loss 2.054293
# iteration 1400 / 1500: loss 2.118515
# iteration 0 / 1500: loss 926.299932
# iteration 100 / 1500: loss 278.428207
# iteration 200 / 1500: loss 84.667954
# iteration 300 / 1500: loss 26.804210
# iteration 400 / 1500: loss 9.458912
# iteration 500 / 1500: loss 4.306553
# iteration 600 / 1500: loss 2.793028
# iteration 700 / 1500: loss 2.280459
# iteration 800 / 1500: loss 2.196245
# iteration 900 / 1500: loss 2.090587
# iteration 1000 / 1500: loss 2.133407
# iteration 1100 / 1500: loss 2.094418
# iteration 1200 / 1500: loss 2.132105
# iteration 1300 / 1500: loss 2.079547
# iteration 1400 / 1500: loss 2.132905
# iteration 0 / 1500: loss 1086.399601
# iteration 100 / 1500: loss 267.110667
# iteration 200 / 1500: loss 66.977077
# iteration 300 / 1500: loss 18.019240
# iteration 400 / 1500: loss 5.994099
# iteration 500 / 1500: loss 3.067595
# iteration 600 / 1500: loss 2.397064
# iteration 700 / 1500: loss 2.195469
# iteration 800 / 1500: loss 2.117493
# iteration 900 / 1500: loss 2.072933
# iteration 1000 / 1500: loss 2.120496
# iteration 1100 / 1500: loss 2.116788
# iteration 1200 / 1500: loss 2.143958
# iteration 1300 / 1500: loss 2.090186
# iteration 1400 / 1500: loss 2.077244
# iteration 0 / 1500: loss 1235.396698
# iteration 100 / 1500: loss 248.375820
# iteration 200 / 1500: loss 51.379901
# iteration 300 / 1500: loss 11.941829
# iteration 400 / 1500: loss 4.098968
# iteration 500 / 1500: loss 2.510552
# iteration 600 / 1500: loss 2.227424
# iteration 700 / 1500: loss 2.103016
# iteration 800 / 1500: loss 2.098401
# iteration 900 / 1500: loss 2.095808
# iteration 1000 / 1500: loss 2.071959
# iteration 1100 / 1500: loss 2.108969
# iteration 1200 / 1500: loss 2.049310
# iteration 1300 / 1500: loss 2.165436
# iteration 1400 / 1500: loss 2.102544
# iteration 0 / 1500: loss 1401.382349
# iteration 100 / 1500: loss 230.802586
# iteration 200 / 1500: loss 39.461953
# iteration 300 / 1500: loss 8.235934
# iteration 400 / 1500: loss 3.116811
# iteration 500 / 1500: loss 2.302149
# iteration 600 / 1500: loss 2.143172
# iteration 700 / 1500: loss 2.065953
# iteration 800 / 1500: loss 2.184242
# iteration 900 / 1500: loss 2.115775
# iteration 1000 / 1500: loss 2.184373
# iteration 1100 / 1500: loss 2.182443
# iteration 1200 / 1500: loss 2.145623
# iteration 1300 / 1500: loss 2.109058
# iteration 1400 / 1500: loss 2.113262
# iteration 0 / 1500: loss 1539.836307
# iteration 100 / 1500: loss 207.584882
# iteration 200 / 1500: loss 29.621231
# iteration 300 / 1500: loss 5.834296
# iteration 400 / 1500: loss 2.597542
# iteration 500 / 1500: loss 2.138610
# iteration 600 / 1500: loss 2.121385
# iteration 700 / 1500: loss 2.171726
# iteration 800 / 1500: loss 2.117342
# iteration 900 / 1500: loss 2.110299
# iteration 1000 / 1500: loss 2.166616
# iteration 1100 / 1500: loss 2.094689
# iteration 1200 / 1500: loss 2.133288
# iteration 1300 / 1500: loss 2.174692
# iteration 1400 / 1500: loss 2.143084
# iteration 0 / 1500: loss 1689.584917
# iteration 100 / 1500: loss 186.228030
# iteration 200 / 1500: loss 22.219282
# iteration 300 / 1500: loss 4.291351
# iteration 400 / 1500: loss 2.439243
# iteration 500 / 1500: loss 2.196596
# iteration 600 / 1500: loss 2.159350
# iteration 700 / 1500: loss 2.172128
# iteration 800 / 1500: loss 2.206540
# iteration 900 / 1500: loss 2.106448
# iteration 1000 / 1500: loss 2.127030
# iteration 1100 / 1500: loss 2.155553
# iteration 1200 / 1500: loss 2.148403
# iteration 1300 / 1500: loss 2.141020
# iteration 1400 / 1500: loss 2.147062
# iteration 0 / 1500: loss 1855.390754
# iteration 100 / 1500: loss 167.145655
# iteration 200 / 1500: loss 16.846872
# iteration 300 / 1500: loss 3.475012
# iteration 400 / 1500: loss 2.272893
# iteration 500 / 1500: loss 2.185324
# iteration 600 / 1500: loss 2.206081
# iteration 700 / 1500: loss 2.134643
# iteration 800 / 1500: loss 2.204322
# iteration 900 / 1500: loss 2.130967
# iteration 1000 / 1500: loss 2.190001
# iteration 1100 / 1500: loss 2.142523
# iteration 1200 / 1500: loss 2.122793
# iteration 1300 / 1500: loss 2.141588
# iteration 1400 / 1500: loss 2.153478
# iteration 0 / 1500: loss 778.618818
# iteration 100 / 1500: loss 105.345681
# iteration 200 / 1500: loss 15.817431
# iteration 300 / 1500: loss 3.902024
# iteration 400 / 1500: loss 2.294989
# iteration 500 / 1500: loss 2.126135
# iteration 600 / 1500: loss 2.117343
# iteration 700 / 1500: loss 2.082577
# iteration 800 / 1500: loss 2.097485
# iteration 900 / 1500: loss 2.007114
# iteration 1000 / 1500: loss 2.047634
# iteration 1100 / 1500: loss 2.123886
# iteration 1200 / 1500: loss 2.033228
# iteration 1300 / 1500: loss 2.048707
# iteration 1400 / 1500: loss 2.101965
# iteration 0 / 1500: loss 919.347850
# iteration 100 / 1500: loss 83.582351
# iteration 200 / 1500: loss 9.391890
# iteration 300 / 1500: loss 2.725952
# iteration 400 / 1500: loss 2.137853
# iteration 500 / 1500: loss 2.135301
# iteration 600 / 1500: loss 2.126192
# iteration 700 / 1500: loss 2.149387
# iteration 800 / 1500: loss 2.105359
# iteration 900 / 1500: loss 2.122286
# iteration 1000 / 1500: loss 2.144902
# iteration 1100 / 1500: loss 2.095593
# iteration 1200 / 1500: loss 2.061277
# iteration 1300 / 1500: loss 2.082717
# iteration 1400 / 1500: loss 2.120755
# iteration 0 / 1500: loss 1079.932106
# iteration 100 / 1500: loss 65.822154
# iteration 200 / 1500: loss 5.916573
# iteration 300 / 1500: loss 2.278699
# iteration 400 / 1500: loss 2.134580
# iteration 500 / 1500: loss 2.156096
# iteration 600 / 1500: loss 2.131737
# iteration 700 / 1500: loss 2.140590
# iteration 800 / 1500: loss 2.100142
# iteration 900 / 1500: loss 2.175483
# iteration 1000 / 1500: loss 2.145164
# iteration 1100 / 1500: loss 2.067883
# iteration 1200 / 1500: loss 2.166349
# iteration 1300 / 1500: loss 2.121109
# iteration 1400 / 1500: loss 2.099201
# iteration 0 / 1500: loss 1251.656700
# iteration 100 / 1500: loss 51.473936
# iteration 200 / 1500: loss 4.066963
# iteration 300 / 1500: loss 2.282749
# iteration 400 / 1500: loss 2.092410
# iteration 500 / 1500: loss 2.137978
# iteration 600 / 1500: loss 2.086980
# iteration 700 / 1500: loss 2.102436
# iteration 800 / 1500: loss 2.122978
# iteration 900 / 1500: loss 2.142021
# iteration 1000 / 1500: loss 2.134120
# iteration 1100 / 1500: loss 2.116517
# iteration 1200 / 1500: loss 2.147518
# iteration 1300 / 1500: loss 2.098001
# iteration 1400 / 1500: loss 2.139425
# iteration 0 / 1500: loss 1384.233218
# iteration 100 / 1500: loss 38.384423
# iteration 200 / 1500: loss 3.142987
# iteration 300 / 1500: loss 2.110694
# iteration 400 / 1500: loss 2.107039
# iteration 500 / 1500: loss 2.148616
# iteration 600 / 1500: loss 2.173708
# iteration 700 / 1500: loss 2.150942
# iteration 800 / 1500: loss 2.156048
# iteration 900 / 1500: loss 2.121038
# iteration 1000 / 1500: loss 2.136490
# iteration 1100 / 1500: loss 2.114263
# iteration 1200 / 1500: loss 2.155642
# iteration 1300 / 1500: loss 2.103803
# iteration 1400 / 1500: loss 2.144800
# iteration 0 / 1500: loss 1537.385199
# iteration 100 / 1500: loss 28.992075
# iteration 200 / 1500: loss 2.629465
# iteration 300 / 1500: loss 2.116346
# iteration 400 / 1500: loss 2.169251
# iteration 500 / 1500: loss 2.107993
# iteration 600 / 1500: loss 2.122625
# iteration 700 / 1500: loss 2.164808
# iteration 800 / 1500: loss 2.155779
# iteration 900 / 1500: loss 2.134639
# iteration 1000 / 1500: loss 2.145095
# iteration 1100 / 1500: loss 2.178200
# iteration 1200 / 1500: loss 2.192712
# iteration 1300 / 1500: loss 2.153509
# iteration 1400 / 1500: loss 2.149346
# iteration 0 / 1500: loss 1681.719994
# iteration 100 / 1500: loss 21.677931
# iteration 200 / 1500: loss 2.429325
# iteration 300 / 1500: loss 2.140536
# iteration 400 / 1500: loss 2.103509
# iteration 500 / 1500: loss 2.148553
# iteration 600 / 1500: loss 2.158783
# iteration 700 / 1500: loss 2.171647
# iteration 800 / 1500: loss 2.172765
# iteration 900 / 1500: loss 2.138877
# iteration 1000 / 1500: loss 2.191781
# iteration 1100 / 1500: loss 2.154348
# iteration 1200 / 1500: loss 2.163961
# iteration 1300 / 1500: loss 2.135877
# iteration 1400 / 1500: loss 2.092067
# iteration 0 / 1500: loss 1882.342590
# iteration 100 / 1500: loss 16.644357
# iteration 200 / 1500: loss 2.287303
# iteration 300 / 1500: loss 2.200175
# iteration 400 / 1500: loss 2.193100
# iteration 500 / 1500: loss 2.128092
# iteration 600 / 1500: loss 2.162438
# iteration 700 / 1500: loss 2.143534
# iteration 800 / 1500: loss 2.097677
# iteration 900 / 1500: loss 2.146003
# iteration 1000 / 1500: loss 2.129944
# iteration 1100 / 1500: loss 2.167150
# iteration 1200 / 1500: loss 2.150895
# iteration 1300 / 1500: loss 2.148671
# iteration 1400 / 1500: loss 2.150628
# iteration 0 / 1500: loss 777.836435
# iteration 100 / 1500: loss 6.974299
# iteration 200 / 1500: loss 2.157596
# iteration 300 / 1500: loss 2.055467
# iteration 400 / 1500: loss 2.080603
# iteration 500 / 1500: loss 2.119801
# iteration 600 / 1500: loss 2.101318
# iteration 700 / 1500: loss 2.071570
# iteration 800 / 1500: loss 2.095718
# iteration 900 / 1500: loss 2.082270
# iteration 1000 / 1500: loss 2.047924
# iteration 1100 / 1500: loss 2.105971
# iteration 1200 / 1500: loss 2.120300
# iteration 1300 / 1500: loss 2.117457
# iteration 1400 / 1500: loss 2.100134
# iteration 0 / 1500: loss 932.449341
# iteration 100 / 1500: loss 4.200672
# iteration 200 / 1500: loss 2.118152
# iteration 300 / 1500: loss 2.073587
# iteration 400 / 1500: loss 2.161218
# iteration 500 / 1500: loss 2.165416
# iteration 600 / 1500: loss 2.103713
# iteration 700 / 1500: loss 2.170724
# iteration 800 / 1500: loss 2.133642
# iteration 900 / 1500: loss 2.108341
# iteration 1000 / 1500: loss 2.077841
# iteration 1100 / 1500: loss 2.124160
# iteration 1200 / 1500: loss 2.101934
# iteration 1300 / 1500: loss 2.133876
# iteration 1400 / 1500: loss 2.104346
# iteration 0 / 1500: loss 1074.555493
# iteration 100 / 1500: loss 2.943754
# iteration 200 / 1500: loss 2.087626
# iteration 300 / 1500: loss 2.102555
# iteration 400 / 1500: loss 2.145784
# iteration 500 / 1500: loss 2.123988
# iteration 600 / 1500: loss 2.107206
# iteration 700 / 1500: loss 2.122819
# iteration 800 / 1500: loss 2.114198
# iteration 900 / 1500: loss 2.085608
# iteration 1000 / 1500: loss 2.146984
# iteration 1100 / 1500: loss 2.093572
# iteration 1200 / 1500: loss 2.116891
# iteration 1300 / 1500: loss 2.141609
# iteration 1400 / 1500: loss 2.166519
# iteration 0 / 1500: loss 1249.524463
# iteration 100 / 1500: loss 2.483671
# iteration 200 / 1500: loss 2.157147
# iteration 300 / 1500: loss 2.115893
# iteration 400 / 1500: loss 2.160360
# iteration 500 / 1500: loss 2.192521
# iteration 600 / 1500: loss 2.111212
# iteration 700 / 1500: loss 2.067984
# iteration 800 / 1500: loss 2.178871
# iteration 900 / 1500: loss 2.109792
# iteration 1000 / 1500: loss 2.121803
# iteration 1100 / 1500: loss 2.121656
# iteration 1200 / 1500: loss 2.137211
# iteration 1300 / 1500: loss 2.092061
# iteration 1400 / 1500: loss 2.164695
# iteration 0 / 1500: loss 1413.435081
# iteration 100 / 1500: loss 2.287251
# iteration 200 / 1500: loss 2.170597
# iteration 300 / 1500: loss 2.102008
# iteration 400 / 1500: loss 2.115557
# iteration 500 / 1500: loss 2.164858
# iteration 600 / 1500: loss 2.132565
# iteration 700 / 1500: loss 2.130506
# iteration 800 / 1500: loss 2.075919
# iteration 900 / 1500: loss 2.114537
# iteration 1000 / 1500: loss 2.151044
# iteration 1100 / 1500: loss 2.172203
# iteration 1200 / 1500: loss 2.131805
# iteration 1300 / 1500: loss 2.136835
# iteration 1400 / 1500: loss 2.089749
# iteration 0 / 1500: loss 1517.627087
# iteration 100 / 1500: loss 2.178312
# iteration 200 / 1500: loss 2.104146
# iteration 300 / 1500: loss 2.127426
# iteration 400 / 1500: loss 2.144473
# iteration 500 / 1500: loss 2.158253
# iteration 600 / 1500: loss 2.123896
# iteration 700 / 1500: loss 2.197485
# iteration 800 / 1500: loss 2.137576
# iteration 900 / 1500: loss 2.169024
# iteration 1000 / 1500: loss 2.168088
# iteration 1100 / 1500: loss 2.094957
# iteration 1200 / 1500: loss 2.172980
# iteration 1300 / 1500: loss 2.125900
# iteration 1400 / 1500: loss 2.131238
# iteration 0 / 1500: loss 1663.126705
# iteration 100 / 1500: loss 2.128304
# iteration 200 / 1500: loss 2.151121
# iteration 300 / 1500: loss 2.162243
# iteration 400 / 1500: loss 2.145281
# iteration 500 / 1500: loss 2.177090
# iteration 600 / 1500: loss 2.134642
# iteration 700 / 1500: loss 2.125595
# iteration 800 / 1500: loss 2.222384
# iteration 900 / 1500: loss 2.160541
# iteration 1000 / 1500: loss 2.178872
# iteration 1100 / 1500: loss 2.184823
# iteration 1200 / 1500: loss 2.163738
# iteration 1300 / 1500: loss 2.179800
# iteration 1400 / 1500: loss 2.154790
# iteration 0 / 1500: loss 1857.948767
# iteration 100 / 1500: loss 2.157261
# iteration 200 / 1500: loss 2.162655
# iteration 300 / 1500: loss 2.180694
# iteration 400 / 1500: loss 2.196490
# iteration 500 / 1500: loss 2.191380
# iteration 600 / 1500: loss 2.188951
# iteration 700 / 1500: loss 2.132900
# iteration 800 / 1500: loss 2.152190
# iteration 900 / 1500: loss 2.164744
# iteration 1000 / 1500: loss 2.170994
# iteration 1100 / 1500: loss 2.175242
# iteration 1200 / 1500: loss 2.148955
# iteration 1300 / 1500: loss 2.172021
# iteration 1400 / 1500: loss 2.115696
# iteration 0 / 1500: loss 770.721692
# iteration 100 / 1500: loss 697.806841
# iteration 200 / 1500: loss 631.208205
# iteration 300 / 1500: loss 571.470987
# iteration 400 / 1500: loss 516.678690
# iteration 500 / 1500: loss 467.353706
# iteration 600 / 1500: loss 423.036344
# iteration 700 / 1500: loss 383.034216
# iteration 800 / 1500: loss 346.174571
# iteration 900 / 1500: loss 313.429136
# iteration 1000 / 1500: loss 283.782515
# iteration 1100 / 1500: loss 256.936647
# iteration 1200 / 1500: loss 232.638651
# iteration 1300 / 1500: loss 210.625650
# iteration 1400 / 1500: loss 190.768228
# iteration 0 / 1500: loss 931.226973
# iteration 100 / 1500: loss 825.707962
# iteration 200 / 1500: loss 732.278002
# iteration 300 / 1500: loss 649.018610
# iteration 400 / 1500: loss 576.052341
# iteration 500 / 1500: loss 510.637083
# iteration 600 / 1500: loss 452.945418
# iteration 700 / 1500: loss 401.900989
# iteration 800 / 1500: loss 356.366386
# iteration 900 / 1500: loss 316.239149
# iteration 1000 / 1500: loss 280.927508
# iteration 1100 / 1500: loss 249.235392
# iteration 1200 / 1500: loss 220.845401
# iteration 1300 / 1500: loss 196.180017
# iteration 1400 / 1500: loss 174.417208
# iteration 0 / 1500: loss 1076.977158
# iteration 100 / 1500: loss 936.305103
# iteration 200 / 1500: loss 814.058764
# iteration 300 / 1500: loss 707.524949
# iteration 400 / 1500: loss 615.150218
# iteration 500 / 1500: loss 534.948356
# iteration 600 / 1500: loss 464.895792
# iteration 700 / 1500: loss 404.220717
# iteration 800 / 1500: loss 351.671126
# iteration 900 / 1500: loss 305.948923
# iteration 1000 / 1500: loss 266.128222
# iteration 1100 / 1500: loss 231.499926
# iteration 1200 / 1500: loss 201.332936
# iteration 1300 / 1500: loss 175.397902
# iteration 1400 / 1500: loss 152.567362
# iteration 0 / 1500: loss 1247.776140
# iteration 100 / 1500: loss 1062.586418
# iteration 200 / 1500: loss 905.800045
# iteration 300 / 1500: loss 771.513209
# iteration 400 / 1500: loss 657.592281
# iteration 500 / 1500: loss 560.340904
# iteration 600 / 1500: loss 477.573105
# iteration 700 / 1500: loss 407.206094
# iteration 800 / 1500: loss 347.244406
# iteration 900 / 1500: loss 296.078646
# iteration 1000 / 1500: loss 252.514159
# iteration 1100 / 1500: loss 215.434201
# iteration 1200 / 1500: loss 183.756372
# iteration 1300 / 1500: loss 156.801299
# iteration 1400 / 1500: loss 133.945343
# iteration 0 / 1500: loss 1408.187961
# iteration 100 / 1500: loss 1176.579111
# iteration 200 / 1500: loss 982.196639
# iteration 300 / 1500: loss 820.597493
# iteration 400 / 1500: loss 685.371163
# iteration 500 / 1500: loss 572.592665
# iteration 600 / 1500: loss 478.258838
# iteration 700 / 1500: loss 399.654341
# iteration 800 / 1500: loss 334.106629
# iteration 900 / 1500: loss 279.258641
# iteration 1000 / 1500: loss 233.421681
# iteration 1100 / 1500: loss 195.204835
# iteration 1200 / 1500: loss 163.480446
# iteration 1300 / 1500: loss 136.824938
# iteration 1400 / 1500: loss 114.502855
# iteration 0 / 1500: loss 1551.424179
# iteration 100 / 1500: loss 1269.532869
# iteration 200 / 1500: loss 1039.086307
# iteration 300 / 1500: loss 850.676264
# iteration 400 / 1500: loss 696.500564
# iteration 500 / 1500: loss 570.449016
# iteration 600 / 1500: loss 467.082469
# iteration 700 / 1500: loss 382.737917
# iteration 800 / 1500: loss 313.445490
# iteration 900 / 1500: loss 256.762560
# iteration 1000 / 1500: loss 210.634117
# iteration 1100 / 1500: loss 172.642476
# iteration 1200 / 1500: loss 141.811673
# iteration 1300 / 1500: loss 116.518904
# iteration 1400 / 1500: loss 95.712499
# iteration 0 / 1500: loss 1684.899101
# iteration 100 / 1500: loss 1351.865264
# iteration 200 / 1500: loss 1084.541700
# iteration 300 / 1500: loss 870.194864
# iteration 400 / 1500: loss 698.780118
# iteration 500 / 1500: loss 560.591228
# iteration 600 / 1500: loss 450.261929
# iteration 700 / 1500: loss 361.402244
# iteration 800 / 1500: loss 290.448061
# iteration 900 / 1500: loss 233.374820
# iteration 1000 / 1500: loss 187.546226
# iteration 1100 / 1500: loss 150.917743
# iteration 1200 / 1500: loss 121.474238
# iteration 1300 / 1500: loss 97.908711
# iteration 1400 / 1500: loss 78.950851
# iteration 0 / 1500: loss 1850.612763
# iteration 100 / 1500: loss 1455.563941
# iteration 200 / 1500: loss 1144.433691
# iteration 300 / 1500: loss 900.391301
# iteration 400 / 1500: loss 708.068504
# iteration 500 / 1500: loss 557.274068
# iteration 600 / 1500: loss 438.520296
# iteration 700 / 1500: loss 345.143578
# iteration 800 / 1500: loss 271.891575
# iteration 900 / 1500: loss 214.257613
# iteration 1000 / 1500: loss 168.855304
# iteration 1100 / 1500: loss 133.226869
# iteration 1200 / 1500: loss 105.266029
# iteration 1300 / 1500: loss 83.160777
# iteration 1400 / 1500: loss 65.879932
# iteration 0 / 1500: loss 766.461490
# iteration 100 / 1500: loss 627.121052
# iteration 200 / 1500: loss 513.428182
# iteration 300 / 1500: loss 420.536247
# iteration 400 / 1500: loss 344.333830
# iteration 500 / 1500: loss 282.041768
# iteration 600 / 1500: loss 231.222130
# iteration 700 / 1500: loss 189.678409
# iteration 800 / 1500: loss 155.401823
# iteration 900 / 1500: loss 127.427320
# iteration 1000 / 1500: loss 104.731437
# iteration 1100 / 1500: loss 86.035599
# iteration 1200 / 1500: loss 70.844401
# iteration 1300 / 1500: loss 58.337982
# iteration 1400 / 1500: loss 48.091575
# iteration 0 / 1500: loss 911.224867
# iteration 100 / 1500: loss 717.145704
# iteration 200 / 1500: loss 563.788573
# iteration 300 / 1500: loss 443.538732
# iteration 400 / 1500: loss 349.202253
# iteration 500 / 1500: loss 274.734083
# iteration 600 / 1500: loss 216.314444
# iteration 700 / 1500: loss 170.475358
# iteration 800 / 1500: loss 134.382530
# iteration 900 / 1500: loss 106.166563
# iteration 1000 / 1500: loss 83.866982
# iteration 1100 / 1500: loss 66.317425
# iteration 1200 / 1500: loss 52.726100
# iteration 1300 / 1500: loss 41.884830
# iteration 1400 / 1500: loss 33.278294
# iteration 0 / 1500: loss 1080.116913
# iteration 100 / 1500: loss 816.046117
# iteration 200 / 1500: loss 616.510424
# iteration 300 / 1500: loss 465.864303
# iteration 400 / 1500: loss 352.389756
# iteration 500 / 1500: loss 266.486217
# iteration 600 / 1500: loss 201.884098
# iteration 700 / 1500: loss 153.092852
# iteration 800 / 1500: loss 116.016958
# iteration 900 / 1500: loss 88.093866
# iteration 1000 / 1500: loss 67.179068
# iteration 1100 / 1500: loss 51.253952
# iteration 1200 / 1500: loss 39.278989
# iteration 1300 / 1500: loss 30.079016
# iteration 1400 / 1500: loss 23.307986
# iteration 0 / 1500: loss 1239.130470
# iteration 100 / 1500: loss 899.597248
# iteration 200 / 1500: loss 653.447750
# iteration 300 / 1500: loss 474.723712
# iteration 400 / 1500: loss 344.856799
# iteration 500 / 1500: loss 250.767915
# iteration 600 / 1500: loss 182.456358
# iteration 700 / 1500: loss 132.981994
# iteration 800 / 1500: loss 97.056839
# iteration 900 / 1500: loss 70.945717
# iteration 1000 / 1500: loss 52.169099
# iteration 1100 / 1500: loss 38.387877
# iteration 1200 / 1500: loss 28.457753
# iteration 1300 / 1500: loss 21.215147
# iteration 1400 / 1500: loss 15.968938
# iteration 0 / 1500: loss 1393.864954
# iteration 100 / 1500: loss 972.201521
# iteration 200 / 1500: loss 678.556132
# iteration 300 / 1500: loss 473.568168
# iteration 400 / 1500: loss 330.528696
# iteration 500 / 1500: loss 231.012213
# iteration 600 / 1500: loss 161.747063
# iteration 700 / 1500: loss 113.452903
# iteration 800 / 1500: loss 79.657101
# iteration 900 / 1500: loss 56.165374
# iteration 1000 / 1500: loss 39.789571
# iteration 1100 / 1500: loss 28.403778
# iteration 1200 / 1500: loss 20.441572
# iteration 1300 / 1500: loss 14.890755
# iteration 1400 / 1500: loss 11.021034
# iteration 0 / 1500: loss 1547.637612
# iteration 100 / 1500: loss 1036.205316
# iteration 200 / 1500: loss 694.260039
# iteration 300 / 1500: loss 465.389572
# iteration 400 / 1500: loss 312.111541
# iteration 500 / 1500: loss 209.770151
# iteration 600 / 1500: loss 141.166565
# iteration 700 / 1500: loss 95.173648
# iteration 800 / 1500: loss 64.509451
# iteration 900 / 1500: loss 43.897612
# iteration 1000 / 1500: loss 30.109130
# iteration 1100 / 1500: loss 20.878555
# iteration 1200 / 1500: loss 14.652014
# iteration 1300 / 1500: loss 10.483470
# iteration 1400 / 1500: loss 7.818635
# iteration 0 / 1500: loss 1667.157401
# iteration 100 / 1500: loss 1073.241751
# iteration 200 / 1500: loss 691.187838
# iteration 300 / 1500: loss 445.247333
# iteration 400 / 1500: loss 287.174090
# iteration 500 / 1500: loss 185.355339
# iteration 600 / 1500: loss 120.047236
# iteration 700 / 1500: loss 78.030474
# iteration 800 / 1500: loss 50.938652
# iteration 900 / 1500: loss 33.512394
# iteration 1000 / 1500: loss 22.334292
# iteration 1100 / 1500: loss 15.125912
# iteration 1200 / 1500: loss 10.516218
# iteration 1300 / 1500: loss 7.525869
# iteration 1400 / 1500: loss 5.629935
# iteration 0 / 1500: loss 1824.513607
# iteration 100 / 1500: loss 1127.908451
# iteration 200 / 1500: loss 697.746680
# iteration 300 / 1500: loss 432.028084
# iteration 400 / 1500: loss 267.918116
# iteration 500 / 1500: loss 166.363546
# iteration 600 / 1500: loss 103.613683
# iteration 700 / 1500: loss 64.893297
# iteration 800 / 1500: loss 40.952625
# iteration 900 / 1500: loss 26.125385
# iteration 1000 / 1500: loss 16.927135
# iteration 1100 / 1500: loss 11.321699
# iteration 1200 / 1500: loss 7.814999
# iteration 1300 / 1500: loss 5.674049
# iteration 1400 / 1500: loss 4.297248
# iteration 0 / 1500: loss 772.879780
# iteration 100 / 1500: loss 467.935308
# iteration 200 / 1500: loss 283.928618
# iteration 300 / 1500: loss 172.626265
# iteration 400 / 1500: loss 105.355991
# iteration 500 / 1500: loss 64.536590
# iteration 600 / 1500: loss 39.923656
# iteration 700 / 1500: loss 24.990531
# iteration 800 / 1500: loss 15.941008
# iteration 900 / 1500: loss 10.505337
# iteration 1000 / 1500: loss 7.146808
# iteration 1100 / 1500: loss 5.188802
# iteration 1200 / 1500: loss 3.929847
# iteration 1300 / 1500: loss 3.235244
# iteration 1400 / 1500: loss 2.763828
# iteration 0 / 1500: loss 920.010677
# iteration 100 / 1500: loss 504.644282
# iteration 200 / 1500: loss 277.096485
# iteration 300 / 1500: loss 152.779681
# iteration 400 / 1500: loss 84.534234
# iteration 500 / 1500: loss 47.203672
# iteration 600 / 1500: loss 26.810667
# iteration 700 / 1500: loss 15.634627
# iteration 800 / 1500: loss 9.521943
# iteration 900 / 1500: loss 6.144277
# iteration 1000 / 1500: loss 4.316274
# iteration 1100 / 1500: loss 3.327057
# iteration 1200 / 1500: loss 2.764284
# iteration 1300 / 1500: loss 2.507412
# iteration 1400 / 1500: loss 2.265223
# iteration 0 / 1500: loss 1072.855986
# iteration 100 / 1500: loss 532.582970
# iteration 200 / 1500: loss 264.465938
# iteration 300 / 1500: loss 131.993674
# iteration 400 / 1500: loss 66.363276
# iteration 500 / 1500: loss 33.943943
# iteration 600 / 1500: loss 17.856916
# iteration 700 / 1500: loss 9.913575
# iteration 800 / 1500: loss 5.968221
# iteration 900 / 1500: loss 4.091631
# iteration 1000 / 1500: loss 3.081721
# iteration 1100 / 1500: loss 2.622485
# iteration 1200 / 1500: loss 2.400018
# iteration 1300 / 1500: loss 2.210927
# iteration 1400 / 1500: loss 2.069149
# iteration 0 / 1500: loss 1233.618395
# iteration 100 / 1500: loss 553.560558
# iteration 200 / 1500: loss 249.024903
# iteration 300 / 1500: loss 112.645423
# iteration 400 / 1500: loss 51.752620
# iteration 500 / 1500: loss 24.341127
# iteration 600 / 1500: loss 12.017426
# iteration 700 / 1500: loss 6.599332
# iteration 800 / 1500: loss 4.065915
# iteration 900 / 1500: loss 2.983025
# iteration 1000 / 1500: loss 2.549007
# iteration 1100 / 1500: loss 2.311436
# iteration 1200 / 1500: loss 2.205248
# iteration 1300 / 1500: loss 2.150078
# iteration 1400 / 1500: loss 2.208376
# iteration 0 / 1500: loss 1365.847557
# iteration 100 / 1500: loss 554.333461
# iteration 200 / 1500: loss 225.950959
# iteration 300 / 1500: loss 92.791013
# iteration 400 / 1500: loss 38.851630
# iteration 500 / 1500: loss 16.959564
# iteration 600 / 1500: loss 8.187602
# iteration 700 / 1500: loss 4.560926
# iteration 800 / 1500: loss 3.116755
# iteration 900 / 1500: loss 2.577199
# iteration 1000 / 1500: loss 2.289821
# iteration 1100 / 1500: loss 2.215287
# iteration 1200 / 1500: loss 2.093035
# iteration 1300 / 1500: loss 2.130834
# iteration 1400 / 1500: loss 2.124408
# iteration 0 / 1500: loss 1558.766984
# iteration 100 / 1500: loss 572.572289
# iteration 200 / 1500: loss 210.863136
# iteration 300 / 1500: loss 78.608139
# iteration 400 / 1500: loss 30.131671
# iteration 500 / 1500: loss 12.393168
# iteration 600 / 1500: loss 5.924276
# iteration 700 / 1500: loss 3.515550
# iteration 800 / 1500: loss 2.725056
# iteration 900 / 1500: loss 2.365054
# iteration 1000 / 1500: loss 2.236071
# iteration 1100 / 1500: loss 2.185620
# iteration 1200 / 1500: loss 2.139419
# iteration 1300 / 1500: loss 2.126027
# iteration 1400 / 1500: loss 2.103981
# iteration 0 / 1500: loss 1696.524056
# iteration 100 / 1500: loss 563.191437
# iteration 200 / 1500: loss 187.986783
# iteration 300 / 1500: loss 63.732388
# iteration 400 / 1500: loss 22.541185
# iteration 500 / 1500: loss 8.926537
# iteration 600 / 1500: loss 4.412159
# iteration 700 / 1500: loss 2.936017
# iteration 800 / 1500: loss 2.395745
# iteration 900 / 1500: loss 2.214298
# iteration 1000 / 1500: loss 2.158951
# iteration 1100 / 1500: loss 2.161377
# iteration 1200 / 1500: loss 2.159181
# iteration 1300 / 1500: loss 2.183181
# iteration 1400 / 1500: loss 2.183544
# iteration 0 / 1500: loss 1839.970615
# iteration 100 / 1500: loss 552.625142
# iteration 200 / 1500: loss 167.119734
# iteration 300 / 1500: loss 51.599799
# iteration 400 / 1500: loss 16.952908
# iteration 500 / 1500: loss 6.554802
# iteration 600 / 1500: loss 3.470768
# iteration 700 / 1500: loss 2.546560
# iteration 800 / 1500: loss 2.256708
# iteration 900 / 1500: loss 2.202818
# iteration 1000 / 1500: loss 2.173903
# iteration 1100 / 1500: loss 2.139338
# iteration 1200 / 1500: loss 2.152702
# iteration 1300 / 1500: loss 2.115279
# iteration 1400 / 1500: loss 2.150711
# lr 1.000000e-08 reg 2.500000e+04 train accuracy: 0.170755 val accuracy: 0.179000
# lr 1.000000e-08 reg 3.000000e+04 train accuracy: 0.182204 val accuracy: 0.179000
# lr 1.000000e-08 reg 3.500000e+04 train accuracy: 0.185490 val accuracy: 0.190000
# lr 1.000000e-08 reg 4.000000e+04 train accuracy: 0.199327 val accuracy: 0.222000
# lr 1.000000e-08 reg 4.500000e+04 train accuracy: 0.212898 val accuracy: 0.220000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.225939 val accuracy: 0.233000
# lr 1.000000e-08 reg 5.500000e+04 train accuracy: 0.217469 val accuracy: 0.216000
# lr 1.000000e-08 reg 6.000000e+04 train accuracy: 0.222143 val accuracy: 0.227000
# lr 2.000000e-08 reg 2.500000e+04 train accuracy: 0.251408 val accuracy: 0.260000
# lr 2.000000e-08 reg 3.000000e+04 train accuracy: 0.268122 val accuracy: 0.264000
# lr 2.000000e-08 reg 3.500000e+04 train accuracy: 0.278306 val accuracy: 0.293000
# lr 2.000000e-08 reg 4.000000e+04 train accuracy: 0.283857 val accuracy: 0.312000
# lr 2.000000e-08 reg 4.500000e+04 train accuracy: 0.287163 val accuracy: 0.304000
# lr 2.000000e-08 reg 5.000000e+04 train accuracy: 0.289551 val accuracy: 0.313000
# lr 2.000000e-08 reg 5.500000e+04 train accuracy: 0.297531 val accuracy: 0.315000
# lr 2.000000e-08 reg 6.000000e+04 train accuracy: 0.300204 val accuracy: 0.324000
# lr 5.000000e-08 reg 2.500000e+04 train accuracy: 0.329347 val accuracy: 0.352000
# lr 5.000000e-08 reg 3.000000e+04 train accuracy: 0.323755 val accuracy: 0.341000
# lr 5.000000e-08 reg 3.500000e+04 train accuracy: 0.316204 val accuracy: 0.330000
# lr 5.000000e-08 reg 4.000000e+04 train accuracy: 0.312694 val accuracy: 0.330000
# lr 5.000000e-08 reg 4.500000e+04 train accuracy: 0.309714 val accuracy: 0.322000
# lr 5.000000e-08 reg 5.000000e+04 train accuracy: 0.304490 val accuracy: 0.322000
# lr 5.000000e-08 reg 5.500000e+04 train accuracy: 0.301816 val accuracy: 0.323000
# lr 5.000000e-08 reg 6.000000e+04 train accuracy: 0.304571 val accuracy: 0.323000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.327490 val accuracy: 0.346000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.320245 val accuracy: 0.331000
# lr 1.000000e-07 reg 3.500000e+04 train accuracy: 0.315673 val accuracy: 0.335000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.305755 val accuracy: 0.326000
# lr 1.000000e-07 reg 4.500000e+04 train accuracy: 0.305796 val accuracy: 0.322000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.308694 val accuracy: 0.322000
# lr 1.000000e-07 reg 5.500000e+04 train accuracy: 0.307551 val accuracy: 0.321000
# lr 1.000000e-07 reg 6.000000e+04 train accuracy: 0.306306 val accuracy: 0.318000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.331061 val accuracy: 0.344000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.324633 val accuracy: 0.329000
# lr 2.000000e-07 reg 3.500000e+04 train accuracy: 0.318449 val accuracy: 0.331000
# lr 2.000000e-07 reg 4.000000e+04 train accuracy: 0.309878 val accuracy: 0.326000
# lr 2.000000e-07 reg 4.500000e+04 train accuracy: 0.313000 val accuracy: 0.324000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.297265 val accuracy: 0.305000
# lr 2.000000e-07 reg 5.500000e+04 train accuracy: 0.308061 val accuracy: 0.318000
# lr 2.000000e-07 reg 6.000000e+04 train accuracy: 0.302367 val accuracy: 0.315000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.319755 val accuracy: 0.328000
# lr 5.000000e-07 reg 3.000000e+04 train accuracy: 0.316449 val accuracy: 0.339000
# lr 5.000000e-07 reg 3.500000e+04 train accuracy: 0.309163 val accuracy: 0.326000
# lr 5.000000e-07 reg 4.000000e+04 train accuracy: 0.304673 val accuracy: 0.313000
# lr 5.000000e-07 reg 4.500000e+04 train accuracy: 0.305714 val accuracy: 0.307000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.311286 val accuracy: 0.309000
# lr 5.000000e-07 reg 5.500000e+04 train accuracy: 0.299653 val accuracy: 0.317000
# lr 5.000000e-07 reg 6.000000e+04 train accuracy: 0.303878 val accuracy: 0.322000
# lr 1.000000e-06 reg 2.500000e+04 train accuracy: 0.301612 val accuracy: 0.328000
# lr 1.000000e-06 reg 3.000000e+04 train accuracy: 0.315245 val accuracy: 0.331000
# lr 1.000000e-06 reg 3.500000e+04 train accuracy: 0.307122 val accuracy: 0.315000
# lr 1.000000e-06 reg 4.000000e+04 train accuracy: 0.301082 val accuracy: 0.322000
# lr 1.000000e-06 reg 4.500000e+04 train accuracy: 0.286592 val accuracy: 0.300000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.285020 val accuracy: 0.299000
# lr 1.000000e-06 reg 5.500000e+04 train accuracy: 0.294939 val accuracy: 0.321000
# lr 1.000000e-06 reg 6.000000e+04 train accuracy: 0.297653 val accuracy: 0.298000
# lr 2.000000e-06 reg 2.500000e+04 train accuracy: 0.305224 val accuracy: 0.321000
# lr 2.000000e-06 reg 3.000000e+04 train accuracy: 0.299245 val accuracy: 0.324000
# lr 2.000000e-06 reg 3.500000e+04 train accuracy: 0.306490 val accuracy: 0.327000
# lr 2.000000e-06 reg 4.000000e+04 train accuracy: 0.298633 val accuracy: 0.306000
# lr 2.000000e-06 reg 4.500000e+04 train accuracy: 0.281327 val accuracy: 0.289000
# lr 2.000000e-06 reg 5.000000e+04 train accuracy: 0.284612 val accuracy: 0.298000
# lr 2.000000e-06 reg 5.500000e+04 train accuracy: 0.291204 val accuracy: 0.295000
# lr 2.000000e-06 reg 6.000000e+04 train accuracy: 0.271082 val accuracy: 0.272000
# lr 5.000000e-06 reg 2.500000e+04 train accuracy: 0.191347 val accuracy: 0.222000
# lr 5.000000e-06 reg 3.000000e+04 train accuracy: 0.236224 val accuracy: 0.248000
# lr 5.000000e-06 reg 3.500000e+04 train accuracy: 0.178653 val accuracy: 0.170000
# lr 5.000000e-06 reg 4.000000e+04 train accuracy: 0.185571 val accuracy: 0.196000
# lr 5.000000e-06 reg 4.500000e+04 train accuracy: 0.211776 val accuracy: 0.198000
# lr 5.000000e-06 reg 5.000000e+04 train accuracy: 0.184490 val accuracy: 0.193000
# lr 5.000000e-06 reg 5.500000e+04 train accuracy: 0.181592 val accuracy: 0.189000
# lr 5.000000e-06 reg 6.000000e+04 train accuracy: 0.134837 val accuracy: 0.130000
# best validation accuracy achieved during cross-validation: 0.352000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.339000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$ True
#
#
# $\color{blue}{\textit Your Explanation:}$ Let's assume that we add a new datapoint that leads to scores [10,8,7], also that the margin for SVM is 2 and the correct class is 1, then the SVM loss of this datapoint will be 0 because it satisfies the margin, i.e., max(0, 8 + 2 - 10) + max(0, 7 + 2 - 10) = 0. Thus, the loss remains unchanged. However, it is not the case for Softmax classifier where the loss will increase, i.e., -log(softmax(10)) = -log(0.84) = 0.17. This occurs because the SVM loss is local objective, that is, it does not care about the details of individual scores only the margin has to be satisfied. On the other hand, the Softmax classifier considers all the individual scores in the calculation of the loss.

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])

# %% [markdown]
# ---
# # IMPORTANT
#
# This is the end of this question. Please do the following:
#
# 1. Click `File -> Save` to make sure the latest checkpoint of this notebook is saved to your Drive.
# 2. Execute the cell below to download the modified `.py` files back to your drive.

# %%
import os

FOLDER_TO_SAVE = os.path.join('drive/My Drive/', FOLDERNAME)
FILES_TO_SAVE = ['cs231n/classifiers/softmax.py']

for files in FILES_TO_SAVE:
  with open(os.path.join(FOLDER_TO_SAVE, '/'.join(files.split('/')[1:])), 'w') as f:
    f.write(''.join(open(files).readlines()))

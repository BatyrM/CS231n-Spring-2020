# %% [markdown]
# <a href="https://colab.research.google.com/github/BatyrM/CS231n-Spring-2020/blob/master/QLNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Clone the project code from github repo

# %%
# !git clone https://github.com/BatyrM/QL-Net.git
# Out:
# Cloning into 'QL-Net'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 57 (delta 32), reused 41 (delta 16), pack-reused 0
# Unpacking objects: 100% (57/57), done.

# %%
#!rm -rf /content/QLNet

# %% [markdown]
# Train baseline model

# %%
# !python QL-Net/train_baseline.py
# Out:
# ...
# 9920512it [00:00, 14860836.29it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# ...
# 32768it [00:00, 173959.71it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# ...
# 1654784it [00:00, 5457065.63it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# ...
# 8192it [00:00, 60154.87it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:469: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
# ...

# %% [markdown]
# Construct look-up table for approximation --> Based on case you want to implement write the case_number as the argument for the parser. case_number >= 4 means you want to construct dictionary for input layer also.
#
# Case number = 1: Implement quantization for layer 1 only
#
# Case number = 2: Implement quantization for layer 2 only
#
# Case number = 3: Implement quantization for both layer 1 and 2
#
# Case number = 4: Implement quantization for input layer only
#
# Case number = 5: Implement quantization for input layer + layer 1
#
# Case number = 6: Implement quantization for input layer + layer 2
#
# Case number = 7: Implement quantization for input layer + layer 1 + layer 2

# %%
! python QL-Net/construct_dict.py --case_number 7
# Out:
# Load activations
# Dimention of data (5, 100, 1, 28, 28)
# Dimention of data (5, 100, 20, 12, 12)
# Dimention of data (5, 100, 40, 4, 4)
# Construct tree input layer
# Node id 0 Density: 1627
# Node id 1 Density: 156
# Node id 2 Density: 28
# Node id 3 Density: 29
# Node id 4 Density: 21
# Node id 5 Density: 31
# Node id 6 Density: 16
# Node id 7 Density: 41
# Node id 8 Density: 25
# Node id 9 Density: 26
# Construct tree layer 1
# Node id 0 Density: 115
# Node id 1 Density: 997
# Node id 2 Density: 125
# Node id 3 Density: 143
# Node id 4 Density: 77
# Node id 5 Density: 164
# Node id 6 Density: 86
# Node id 7 Density: 79
# Node id 8 Density: 134
# Node id 9 Density: 80
# Construct tree layer 2
# Node id 0 Density: 137
# Node id 1 Density: 172
# Node id 2 Density: 235
# Node id 3 Density: 133
# Node id 4 Density: 247
# Node id 5 Density: 280
# Node id 6 Density: 220
# Node id 7 Density: 190
# Node id 8 Density: 241
# Node id 9 Density: 145

# %% [markdown]
# You have 7 different cases for different layers quantization. In order to train quantized model you MUST PROVIDE case number as a parsing argument so that program will know what you want to implement.
#
# These are the 7 possible cases:
#
# Case number = 1: Implement quantization for layer 1 only
#
# Case number = 2: Implement quantization for layer 2 only
#
# Case number = 3: Implement quantization for both layer 1 and 2
#
# Case number = 4: Implement quantization for input layer only
#
# Case number = 5: Implement quantization for input layer + layer 1
#
# Case number = 6: Implement quantization for input layer + layer 2
#
# Case number = 7: Implement quantization for input layer + layer 1 + layer 2

# %%
# !python QL-Net/train_quantized.py --case_number 7
# Out:
# torch.Size([1, 10, 1])
# torch.Size([1, 10, 20])
# torch.Size([1, 10, 40])
#
#
# With both layers + input layer quantized:
#
# Train Epoch: 0 [0/60000 (0%)]	Loss: 0.728160	Accuracy: 81.00
# Train Epoch: 0 [3000/60000 (5%)]	Loss: 0.157494	Accuracy: 95.00
# Train Epoch: 0 [6000/60000 (10%)]	Loss: 0.323349	Accuracy: 92.00
# Train Epoch: 0 [9000/60000 (15%)]	Loss: 0.303345	Accuracy: 89.00
# Train Epoch: 0 [12000/60000 (20%)]	Loss: 0.194175	Accuracy: 94.00
# Train Epoch: 0 [15000/60000 (25%)]	Loss: 0.336774	Accuracy: 92.00
# Train Epoch: 0 [18000/60000 (30%)]	Loss: 0.262745	Accuracy: 89.00
# Train Epoch: 0 [21000/60000 (35%)]	Loss: 0.212075	Accuracy: 90.00
# Train Epoch: 0 [24000/60000 (40%)]	Loss: 0.389765	Accuracy: 89.00
# Train Epoch: 0 [27000/60000 (45%)]	Loss: 0.262603	Accuracy: 92.00
# Train Epoch: 0 [30000/60000 (50%)]	Loss: 0.212458	Accuracy: 94.00
# Train Epoch: 0 [33000/60000 (55%)]	Loss: 0.323521	Accuracy: 92.00
# ...

# %% [markdown]
# Method: closest to centroids
#
# Lookup Table Input Layer Size: [1, 10, 1]
#
# Lookup Table Layer 1 Size: [1, 10, 20]
#
# Lookup Table Layer 2 Size: [1, 10, 40]
#
# Case 1: First layer quantized --- Accuracy: 98.49 %
#
# Case 2: Second layer quantized --- Accuracy: 94.83 %
#
# Case 3: First + Second layers quantized --- Accuracy: 95.44 %
#
# Case 4: Input layer quantized --- Accuracy: 99.24 %
#
# Case 5: Input + First layers quantized --- Accuracy: 98.48 %
#
# Case 6: Input + Second layers quantized --- Accuracy: 95.32 %
#
# Case 7: Input + First + Second layers quantized --- Accuracy: 94.83 %
